# %% [markdown]
# <a href="https://colab.research.google.com/github/Jair-pc/Dio_Processamento_de_imagens_em_Python/blob/master/Testando_Pacote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Testando o Pacote de Processamento de Imagens em Python
# **Segue alguns testes para verificar a utilidade da biblioteca criada**
#
# **Python para Cientistas de Dados**
#
# Este documento segue em constante evolução

# %%
from processador_imagem_virtual.util import io, plot
from processador_imagem_virtual.processando import combinacao, transformacao

# %%
imagem1 = io.ler_imagem("lake-g793b7d422_1920.jpg")
imagem2 = io.ler_imagem("flower-gf724be541_1920.jpg")

# %%
plot.plot_imagem(imagem1)
plot.plot_imagem(imagem2)

# %%
imagem_correspondente = combinacao.transferindo_histograma_dupla(imagem1, imagem2)
plot.plot_imagem(imagem_correspondente)

# %%
imagem3 = io.ler_imagem("img04.jpg")
imagem4 = io.ler_imagem("img03.jpg")

# %%
plot.plot_imagem(imagem3)
plot.plot_imagem(imagem4)

# %%
imagem_correspondente = combinacao.transferindo_histograma_dupla(imagem3, imagem4)
plot.plot_imagem(imagem_correspondente)

# %%
imagem_correspondente = combinacao.transferindo_histograma_dupla(imagem1, imagem4)
plot.plot_imagem(imagem_correspondente)
